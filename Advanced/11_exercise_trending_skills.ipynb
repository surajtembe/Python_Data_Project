# %% [markdown]
# # Exercise - Investigate Treding Skills

# %%
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt
import ast

# Load Dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Dataframe cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month
# Out:
#        job_title_short  ... job_posted_month_no
# 1         Data Analyst  ...                   1
# 12        Data Analyst  ...                  12
# 18        Data Analyst  ...                  10
# 31        Data Analyst  ...                  10
# 34        Data Analyst  ...                   2
# ...                ...  ...                 ...
# 785703    Data Analyst  ...                   1
# 785705    Data Analyst  ...                   1
# 785715    Data Analyst  ...                   3
# 785717    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
#
# [196075 rows x 19 columns]

# %%
df_DA_exploded = df_DA.explode('job_skills')
df_DA_exploded
# Out:
#        job_title_short  ... job_posted_month_no
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# ...                ...  ...                 ...
# 785717    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
#
# [672513 rows x 19 columns]

# %%
df_DA_pivot = df_DA_exploded.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
# Out:
# job_skills           airflow  airtable  alteryx  ...  xamarin  yarn  zoom
# job_posted_month_no                              ...
# 1                        197        17      551  ...        0     9    95
# 2                        169         2      448  ...        0     4    41
# 3                        181         4      442  ...        1     5    45
# 4                        155         4      413  ...        0     6    26
# 5                        128         8      310  ...        0     7    18
# 6                        164        14      393  ...        0    11    34
# 7                        207         4      366  ...        0     6    38
# 8                        197         3      413  ...        0    11    41
# 9                        118         4      317  ...        0     5    25
# 10                       173        11      350  ...        1     4    39
# 11                       169         7      293  ...        0     6    26
# 12                       144        10      274  ...        0     2    37
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills             sql  excel  python  ...  capacitor  chainer  msaccess
# job_posted_month_no                        ...
# 1                    11336   8170    6606  ...          1        0         0
# 2                     7947   5772    4751  ...          0        0         0
# 3                     7868   5675    4741  ...          0        0         0
# 4                     7553   5496    4557  ...          0        0         0
# 5                     6617   4773    4070  ...          0        0         1
# 6                     7584   5724    4707  ...          0        0         0
# 7                     7687   5513    4831  ...          0        0         0
# 8                     8823   6482    5576  ...          0        0         0
# 9                     6829   4886    4229  ...          0        0         0
# 10                    7474   5217    4693  ...          0        0         0
# 11                    6652   4776    4233  ...          0        0         0
# 12                    6058   4376    4196  ...          0        1         0
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.iloc[:, :5].plot(kind='line')
plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()
